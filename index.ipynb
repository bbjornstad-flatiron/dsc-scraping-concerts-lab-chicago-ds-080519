# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from numpy import nan, random

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
def scrape_events(events_page_url):
    page = requests.get(events_page_url)
    assert(page.status_code == 200)
    
    soup = BeautifulSoup(page.content)
    
    # find all event-items
    events = soup.find_all(class_='event-item')
    
    cols = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    
    names = []
    venues = []
    dates = []
    noa = []
    
    for event in events:
        event_title = event.find(class_='event-title').get_text().split(sep=' at ')
        event_name = event_title[0]
        event_venue = event_title[1]
        attending = event.find(class_='attending')
        try:
            attending = int(attending.get_text()[0])
        except:
            attending = nan
        
        event_date = event.find('time').get_text()
        names.append(event_name)
        venues.append(event_venue)
        dates.append(event_date)
        noa.append(attending)
        
    df_dict = {cols[0]: names, cols[1]: venues, cols[2]: dates, cols[3]: noa}

    df = pd.DataFrame.from_dict(df_dict)
    df.Event_Date = pd.to_datetime(df.Event_Date, infer_datetime_format=True)
    
    return df

scrape_events('https://www.residentadvisor.net/events')
# Out:
#                                            Event_Name  \
# 0   5 Mag Welcomes Junior Sanchez / Gene Hunt / Cz...
# 1                     Joris Voorn: Beats On The Beach
# 2                     Paradigm Underground ft Rebekah
# 3                  Utopia presents Hieroglyphic Being
# 4             The Function with Maliibu Miitch - Live
# 5   Material with Colette / Dajae / Diz / DJ Heath...
# 6                               Matthew Dear (DJ Set)
# 7                Midway Hustle Record's Release Party
# 8   SEA of Fools with Dēacön Blü, Duke Grip & Gues...
# 9                                      House of Efunk
# 10            Queen! Labor Day Edition (All-Building)
# 11                 Road To Imagine Festival - Chicago
# 12              Overly Drumatic with The Carry Nation
# 13                                   H.A.S. x N.B.F.C
# 14  Speak Easy Deeper House - Composition/Mixing/P...
# 15  Deliverance with Terry Hunter Sunday Labor Day...
# 16                                 Japanese Funk Nite
# 17  Manifest with Abigail / Deepsmith / J Copes / ...
#
#                       Venue Event_Date  Number_of_Attendees
# 0                  smartbar 2019-08-30                  1.0
# 1                 Castaways 2019-08-30                  2.0
# 2       Secret Location TBA 2019-08-30                  1.0
# 3                      Exit 2019-08-30                  6.0
# 4               Le Nocturne 2019-08-30                  3.0
# 5                  smartbar 2019-08-31                  2.0
# 6                    Spybar 2019-08-31                  5.0
# 7        Gramaphone Records 2019-08-31                  3.0
# 8                    Cerise 2019-08-31                  1.0
# 9       Space Stage Studios 2019-09-01                  3.0
# 10                 smartbar 2019-09-01                  7.0
# 11            TBA - Chicago 2019-09-01                  7.0
# 12                Ace Hotel 2019-09-01                  4.0
# 13            TBA - Chicago 2019-09-01                  NaN
# 14            TBA - Chicago 2019-09-01                  NaN
# 15  Renaissance Bronzeville 2019-09-01                  NaN
# 16              Punch House 2019-09-04                  NaN
# 17                 smartbar 2019-09-05                  4.0

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    page = requests.get(url)
    assert(page.status_code == 200)
    
    soup = BeautifulSoup(page.content)
    
    next_item = soup.find(id='liNext')
    next_page_url = next_item.a.get('href')
    
    next_page_url = 'https://www.residentadvisor.net' + next_page_url
    
    return next_page_url

next_page('https://www.residentadvisor.net/events')
# Out:
# 'https://www.residentadvisor.net/events/us/chicago/week/2019-09-06'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
# so that we don't get blocked by the system
from time import sleep

#Your code here
def scrape_n_events(n):
    url = 'https://www.residentadvisor.net/events'
    print(url)
    df = scrape_events(url)
    while len(df.index) < n:
        print(len(df.index))
        url = next_page(url)
        print(url)
        df = pd.concat([df, scrape_events(url)])
        wait_time = 2*random.random()
        sleep(wait_time)

    return df

# investigation reveals only 77 events for a while, so we'll only scrape 50 of them.
thousand_events = scrape_n_events(50)
thousand_events
# Out:
# https://www.residentadvisor.net/events
# 18
# https://www.residentadvisor.net/events/us/chicago/week/2019-09-06
# 30
# https://www.residentadvisor.net/events/us/chicago/week/2019-09-13
# 38
# https://www.residentadvisor.net/events/us/chicago/week/2019-09-20
# 44
# https://www.residentadvisor.net/events/us/chicago/week/2019-09-27
#                                            Event_Name  \
# 0   5 Mag Welcomes Junior Sanchez / Gene Hunt / Cz...
# 1                     Joris Voorn: Beats On The Beach
# 2                     Paradigm Underground ft Rebekah
# 3                  Utopia presents Hieroglyphic Being
# 4             The Function with Maliibu Miitch - Live
# 5   Material with Colette / Dajae / Diz / DJ Heath...
# 6                               Matthew Dear (DJ Set)
# 7                Midway Hustle Record's Release Party
# 8   SEA of Fools with Dēacön Blü, Duke Grip & Gues...
# 9                                      House of Efunk
# 10            Queen! Labor Day Edition (All-Building)
# 11                 Road To Imagine Festival - Chicago
# 12              Overly Drumatic with The Carry Nation
# 13                                   H.A.S. x N.B.F.C
# 14  Speak Easy Deeper House - Composition/Mixing/P...
# 15  Deliverance with Terry Hunter Sunday Labor Day...
# 16                                 Japanese Funk Nite
# 17  Manifest with Abigail / Deepsmith / J Copes / ...
# 0                 Format x Sleepwalker present: FJAAK
# 1   Paranoid London (Live) / Justin Aulis Long / B...
# 2                                       Chris Liebing
# 3                                  Different Standard
# 4                     Flannel Fridays with DJ Goodboy
# 5   RSD Summer Closer: Rafael Cancian x Peter Croc...
# 6   Obscure Welcomes Terrence Dixon (Live) / Lowki...
# 7   Speak Easy Deeper House - Composition/Mixing/P...
# 8   Queen! with Derrick Carter / Michael Serafini ...
# 9                                      Massive Attack
# 10                Spybar & Nightsweat presents: Dax J
# 11  Research & Development with Circa Tapes (Live)...
# 0                     Obscure 033: Scuba presents SCB
# 1   Relate with DJ Slugo / Erika Glück / Professor...
# 2                         Rosebud with Mikeq (DJ Set)
# 3                                      Tokyo Disko II
# 4   The Function with Vladimir Ivkovic / Traxx / J...
# 5                                           Afterburn
# 6   Speak Easy Deeper House - Composition/Mixing/P...
# 7    Canopy Sounds: Robbie Akbal & Christian Voldstad
# 0       Body Response Feat. Gene On Earth & The Ghost
# 1                               Punk the Burbs Fest 3
# 2          Yehme2's Mom & Dad's Residency - September
# 3                                   シティポップ 『City Pop』
# 4              Locals with Mel Hammond / DNS / Mathis
# 5   Speak Easy Deeper House - Composition/Mixing/P...
# 0                  J.Phlip / Paul Johnson / Duke Shin
# 1   Front Left Speaker with Sassmouth / Mark Therb...
# 2           The Black Madonna / Peach / Phillip Stone
# 3   Astral Undertones presents Lindsey Herbert / J...
# 4   Speak Easy Deeper House - Composition/Mixing/P...
# 5   Mid-Week Queen! with Cerrone / Michael Serafin...
# 6     Grün Wasser 'Not Ok with Things' Record Release
# 7                                 Phunk Junk Takeover
#
#                              Venue Event_Date  Number_of_Attendees
# 0                         smartbar 2019-08-30                  1.0
# 1                        Castaways 2019-08-30                  2.0
# 2              Secret Location TBA 2019-08-30                  1.0
# 3                             Exit 2019-08-30                  6.0
# 4                      Le Nocturne 2019-08-30                  3.0
# 5                         smartbar 2019-08-31                  2.0
# 6                           Spybar 2019-08-31                  5.0
# 7               Gramaphone Records 2019-08-31                  3.0
# 8                           Cerise 2019-08-31                  1.0
# 9              Space Stage Studios 2019-09-01                  3.0
# 10                        smartbar 2019-09-01                  7.0
# 11                   TBA - Chicago 2019-09-01                  7.0
# 12                       Ace Hotel 2019-09-01                  4.0
# 13                   TBA - Chicago 2019-09-01                  NaN
# 14                   TBA - Chicago 2019-09-01                  NaN
# 15         Renaissance Bronzeville 2019-09-01                  NaN
# 16                     Punch House 2019-09-04                  NaN
# 17                        smartbar 2019-09-05                  4.0
# 0                    TBA - Chicago 2019-09-06                  9.0
# 1                         smartbar 2019-09-06                  1.0
# 2                           Spybar 2019-09-06                  1.0
# 3                    TBA - Chicago 2019-09-06                  4.0
# 4                      Le Nocturne 2019-09-06                  2.0
# 5                           Cerise 2019-09-06                  1.0
# 6                         smartbar 2019-09-07                  1.0
# 7                    TBA - Chicago 2019-09-08                  1.0
# 8                         smartbar 2019-09-08                  1.0
# 9              The Chicago Theatre 2019-09-11                  1.0
# 10                          Spybar 2019-09-12                  6.0
# 11                        smartbar 2019-09-12                  2.0
# 0                    TBA - Chicago 2019-09-13                  4.0
# 1                         smartbar 2019-09-13                  9.0
# 2                      Le Nocturne 2019-09-13                  1.0
# 3                 Sleeping Village 2019-09-13                  NaN
# 4                         smartbar 2019-09-14                  8.0
# 5                    TBA - Chicago 2019-09-14                  3.0
# 6                    TBA - Chicago 2019-09-15                  1.0
# 7                          Arbella 2019-09-15                  1.0
# 0              Secret Location TBA 2019-09-20                  1.0
# 1                     Basecamp Pub 2019-09-20                  NaN
# 2                 Sleeping Village 2019-09-21                  1.0
# 3   Murasaki Sake & Karaoke Lounge 2019-09-21                  1.0
# 4                         Underbar 2019-09-21                  NaN
# 5                    TBA - Chicago 2019-09-22                  2.0
# 0                         smartbar 2019-09-27                  9.0
# 1                         smartbar 2019-09-27                  2.0
# 2                         smartbar 2019-09-28                  1.0
# 3                    TBA - Chicago 2019-09-28                  1.0
# 4                    TBA - Chicago 2019-09-29                  1.0
# 5                         smartbar 2019-10-02                  6.0
# 6                 Sleeping Village 2019-10-03                  2.0
# 7                     Bass Station 2019-10-03                  NaN

# %%
thousand_events.sort_values(by=['Number_of_Attendees', 'Event_Date'], ascending=False)
# Out:
#                                            Event_Name  \
# 0                  J.Phlip / Paul Johnson / Duke Shin
# 1   Relate with DJ Slugo / Erika Glück / Professor...
# 0                 Format x Sleepwalker present: FJAAK
# 4   The Function with Vladimir Ivkovic / Traxx / J...
# 10            Queen! Labor Day Edition (All-Building)
# 11                 Road To Imagine Festival - Chicago
# 5   Mid-Week Queen! with Cerrone / Michael Serafin...
# 10                Spybar & Nightsweat presents: Dax J
# 3                  Utopia presents Hieroglyphic Being
# 6                               Matthew Dear (DJ Set)
# 0                     Obscure 033: Scuba presents SCB
# 3                                  Different Standard
# 17  Manifest with Abigail / Deepsmith / J Copes / ...
# 12              Overly Drumatic with The Carry Nation
# 5                                           Afterburn
# 9                                      House of Efunk
# 7                Midway Hustle Record's Release Party
# 4             The Function with Maliibu Miitch - Live
# 6     Grün Wasser 'Not Ok with Things' Record Release
# 1   Front Left Speaker with Sassmouth / Mark Therb...
# 5   Speak Easy Deeper House - Composition/Mixing/P...
# 11  Research & Development with Circa Tapes (Live)...
# 4                     Flannel Fridays with DJ Goodboy
# 5   Material with Colette / Dajae / Diz / DJ Heath...
# 1                     Joris Voorn: Beats On The Beach
# 4   Speak Easy Deeper House - Composition/Mixing/P...
# 2           The Black Madonna / Peach / Phillip Stone
# 3   Astral Undertones presents Lindsey Herbert / J...
# 2          Yehme2's Mom & Dad's Residency - September
# 3                                   シティポップ 『City Pop』
# 0       Body Response Feat. Gene On Earth & The Ghost
# 6   Speak Easy Deeper House - Composition/Mixing/P...
# 7    Canopy Sounds: Robbie Akbal & Christian Voldstad
# 2                         Rosebud with Mikeq (DJ Set)
# 9                                      Massive Attack
# 7   Speak Easy Deeper House - Composition/Mixing/P...
# 8   Queen! with Derrick Carter / Michael Serafini ...
# 6   Obscure Welcomes Terrence Dixon (Live) / Lowki...
# 1   Paranoid London (Live) / Justin Aulis Long / B...
# 2                                       Chris Liebing
# 5   RSD Summer Closer: Rafael Cancian x Peter Croc...
# 8   SEA of Fools with Dēacön Blü, Duke Grip & Gues...
# 0   5 Mag Welcomes Junior Sanchez / Gene Hunt / Cz...
# 2                     Paradigm Underground ft Rebekah
# 7                                 Phunk Junk Takeover
# 4              Locals with Mel Hammond / DNS / Mathis
# 1                               Punk the Burbs Fest 3
# 3                                      Tokyo Disko II
# 16                                 Japanese Funk Nite
# 13                                   H.A.S. x N.B.F.C
# 14  Speak Easy Deeper House - Composition/Mixing/P...
# 15  Deliverance with Terry Hunter Sunday Labor Day...
#
#                              Venue Event_Date  Number_of_Attendees
# 0                         smartbar 2019-09-27                  9.0
# 1                         smartbar 2019-09-13                  9.0
# 0                    TBA - Chicago 2019-09-06                  9.0
# 4                         smartbar 2019-09-14                  8.0
# 10                        smartbar 2019-09-01                  7.0
# 11                   TBA - Chicago 2019-09-01                  7.0
# 5                         smartbar 2019-10-02                  6.0
# 10                          Spybar 2019-09-12                  6.0
# 3                             Exit 2019-08-30                  6.0
# 6                           Spybar 2019-08-31                  5.0
# 0                    TBA - Chicago 2019-09-13                  4.0
# 3                    TBA - Chicago 2019-09-06                  4.0
# 17                        smartbar 2019-09-05                  4.0
# 12                       Ace Hotel 2019-09-01                  4.0
# 5                    TBA - Chicago 2019-09-14                  3.0
# 9              Space Stage Studios 2019-09-01                  3.0
# 7               Gramaphone Records 2019-08-31                  3.0
# 4                      Le Nocturne 2019-08-30                  3.0
# 6                 Sleeping Village 2019-10-03                  2.0
# 1                         smartbar 2019-09-27                  2.0
# 5                    TBA - Chicago 2019-09-22                  2.0
# 11                        smartbar 2019-09-12                  2.0
# 4                      Le Nocturne 2019-09-06                  2.0
# 5                         smartbar 2019-08-31                  2.0
# 1                        Castaways 2019-08-30                  2.0
# 4                    TBA - Chicago 2019-09-29                  1.0
# 2                         smartbar 2019-09-28                  1.0
# 3                    TBA - Chicago 2019-09-28                  1.0
# 2                 Sleeping Village 2019-09-21                  1.0
# 3   Murasaki Sake & Karaoke Lounge 2019-09-21                  1.0
# 0              Secret Location TBA 2019-09-20                  1.0
# 6                    TBA - Chicago 2019-09-15                  1.0
# 7                          Arbella 2019-09-15                  1.0
# 2                      Le Nocturne 2019-09-13                  1.0
# 9              The Chicago Theatre 2019-09-11                  1.0
# 7                    TBA - Chicago 2019-09-08                  1.0
# 8                         smartbar 2019-09-08                  1.0
# 6                         smartbar 2019-09-07                  1.0
# 1                         smartbar 2019-09-06                  1.0
# 2                           Spybar 2019-09-06                  1.0
# 5                           Cerise 2019-09-06                  1.0
# 8                           Cerise 2019-08-31                  1.0
# 0                         smartbar 2019-08-30                  1.0
# 2              Secret Location TBA 2019-08-30                  1.0
# 7                     Bass Station 2019-10-03                  NaN
# 4                         Underbar 2019-09-21                  NaN
# 1                     Basecamp Pub 2019-09-20                  NaN
# 3                 Sleeping Village 2019-09-13                  NaN
# 16                     Punch House 2019-09-04                  NaN
# 13                   TBA - Chicago 2019-09-01                  NaN
# 14                   TBA - Chicago 2019-09-01                  NaN
# 15         Renaissance Bronzeville 2019-09-01                  NaN

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
